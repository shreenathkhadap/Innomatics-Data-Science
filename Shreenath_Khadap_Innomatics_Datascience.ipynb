# %% [markdown]
# Manish Dhorepatil
# *Innomatics Data Science Internship |  Entrance Test (Part 2) | Hackathon*

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a1ba475b-1923-4a6e-b536-d7b4af8db52b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a1ba475b-1923-4a6e-b536-d7b4af8db52b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
f2 = pd.read_csv("movies.csv")
f3 = pd.read_csv("tags.csv")
f4 = pd.read_csv("ratings.csv")
f1 = pd.read_csv("links.csv")

# %%
f2.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
f4.shape
# Out:
# (100836, 4)

# %%
f4.head(5)
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
f4['userId'].nunique()
# Out:
# 610

# %%
f1
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9737   193581  5476944  432131.0
# 9738   193583  5914996  445030.0
# 9739   193585  6397426  479308.0
# 9740   193587  8391976  483455.0
# 9741   193609   101726   37891.0
#
# [9742 rows x 3 columns]

# %%
f2
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
f3
# Out:
#       userId  movieId               tag   timestamp
# 0          2    60756             funny  1445714994
# 1          2    60756   Highly quotable  1445714996
# 2          2    60756      will ferrell  1445714992
# 3          2    89774      Boxing story  1445715207
# 4          2    89774               MMA  1445715200
# ...      ...      ...               ...         ...
# 3678     606     7382         for katie  1171234019
# 3679     606     7936           austere  1173392334
# 3680     610     3265            gun fu  1493843984
# 3681     610     3265  heroic bloodshed  1493843978
# 3682     610   168248  Heroic Bloodshed  1493844270
#
# [3683 rows x 4 columns]

# %%
f4
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
f2[f2['title']=='Matrix, The (1999)']
# Out:
#       movieId               title                  genres
# 1939     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller

# %%
f3[f3['movieId']==2571]
# Out:
#       userId  movieId                 tag   timestamp
# 815      424     2571        martial arts  1457842912
# 816      424     2571              sci-fi  1457842899
# 1646     474     2571  alternate universe  1137204991
# 2794     537     2571          philosophy  1424141098
# 2795     537     2571    post apocalyptic  1424141101

# %%
f4[f4['rating']==5.0]
# Out:
#         userId  movieId  rating   timestamp
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# 6            1      101     5.0   964980868
# 8            1      151     5.0   964984041
# 9            1      157     5.0   964984100
# ...        ...      ...     ...         ...
# 100814     610   158238     5.0  1479545219
# 100829     610   164179     5.0  1493845631
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
#
# [13211 rows x 4 columns]

# %%
# Load the datasets
links = pd.read_csv('links.csv')
movies = pd.read_csv('movies.csv')
ratings = pd.read_csv('ratings.csv')
tags = pd.read_csv('tags.csv')

# %%
links.head(5)
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
movies.head(5)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings.head(5)
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
tags.head(5)
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
merged_data = pd.merge(ratings, movies, on='movieId', how='left')
merged_data = pd.merge(merged_data, links, on='movieId', how='left')
merged_data = pd.merge(merged_data, tags, on=['userId', 'movieId', 'timestamp'], how='left')

# Save the merged data to a new CSV file
merged_data.to_csv('merged_data.csv', index=False)

# %%
m1 = pd.read_csv('merged_data.csv')

m1.head()
# Out:
#    userId  movieId  rating  timestamp                        title  \
# 0       1        1     4.0  964982703             Toy Story (1995)
# 1       1        3     4.0  964981247      Grumpier Old Men (1995)
# 2       1        6     4.0  964982224                  Heat (1995)
# 3       1       47     5.0  964983815  Seven (a.k.a. Se7en) (1995)
# 4       1       50     5.0  964982931   Usual Suspects, The (1995)
#
#                                         genres  imdbId   tmdbId  tag
# 0  Adventure|Animation|Children|Comedy|Fantasy  114709    862.0  NaN
# 1                               Comedy|Romance  113228  15602.0  NaN
# 2                        Action|Crime|Thriller  113277    949.0  NaN
# 3                             Mystery|Thriller  114369    807.0  NaN
# 4                       Crime|Mystery|Thriller  114814    629.0  NaN

# %%
max_ratings_movie = m1.groupby('title')['rating'].count().idxmax()

# Print the title of the movie with the maximum number of ratings
print("Movie with the maximum number of user ratings:", max_ratings_movie)
# Out:
# Movie with the maximum number of user ratings: Forrest Gump (1994)

# %%
terminator_2_ratings = m1[m1['title'] == 'Terminator 2: Judgment Day (1991)']

# Calculate the average user rating
average_rating = terminator_2_ratings['rating'].mean()

# Print the average user rating
print("Average user rating for Terminator 2: Judgment Day (1991):", average_rating)
# Out:
# Average user rating for Terminator 2: Judgment Day (1991): 3.970982142857143

# %%
fight_club_ratings = m1[m1['title'] == 'Fight Club (1999)']

# Plot the histogram of user ratings
plt.figure(figsize=(10, 6))
plt.hist(fight_club_ratings['rating'], bins=5, edgecolor='black')
plt.title('User Ratings Distribution for Fight Club (1999)')
plt.xlabel('Rating')
plt.ylabel('Number of Users')
plt.show()

# %%
# 1. Group user ratings based on movieId and apply aggregation operations
grouped_ratings = ratings.groupby('movieId').agg({'rating': ['count', 'mean']}).reset_index()
grouped_ratings.columns = ['movieId', 'rating_count', 'rating_mean']

# 2. Apply inner join on dataframe created from movies.csv and the grouped df from step 1
merged_data1 = pd.merge(movies, grouped_ratings, on='movieId', how='inner')

# 3. Filter only those movies which have more than 50 user ratings
filtered_data = merged_data1[merged_data1['rating_count'] > 50]

# Display the first few rows of the filtered data
print(filtered_data.head())
# Out:
#    movieId                    title  \
# 0        1         Toy Story (1995)
# 1        2           Jumanji (1995)
# 2        3  Grumpier Old Men (1995)
# 5        6              Heat (1995)
# 6        7           Sabrina (1995)
#
#                                         genres  rating_count  rating_mean
# 0  Adventure|Animation|Children|Comedy|Fantasy           215     3.920930
# 1                   Adventure|Children|Fantasy           110     3.431818
# 2                               Comedy|Romance            52     3.259615
# 5                        Action|Crime|Thriller           102     3.946078
# 6                               Comedy|Romance            54     3.185185

# %%
most_popular_movie = filtered_data.loc[filtered_data['rating_mean'].idxmax()]

print("The most popular movie based on average user ratings is:", most_popular_movie['title'])
# Out:
# The most popular movie based on average user ratings is: Shawshank Redemption, The (1994)

# %%
top_movies_by_ratings = filtered_data.sort_values(by='rating_count', ascending=False)

# Select the top 5 movies
top_5_movies = top_movies_by_ratings.head(5)

# Display the titles of the top 5 movies
print("Top 5 popular movies based on number of user ratings:")
print(top_5_movies[['title', 'rating_count']])
# Out:
# Top 5 popular movies based on number of user ratings:
#                                  title  rating_count
# 314                Forrest Gump (1994)           329
# 277   Shawshank Redemption, The (1994)           317
# 257                Pulp Fiction (1994)           307
# 510   Silence of the Lambs, The (1991)           279
# 1938                Matrix, The (1999)           278

# %%
# Filter only Sci-Fi movies
sci_fi_movies = filtered_data[filtered_data['genres'].str.contains('Sci-Fi')]

# Sort the Sci-Fi movies based on rating_count in descending order
sorted_sci_fi_movies = sci_fi_movies.sort_values(by='rating_count', ascending=False)

# Select the third most popular Sci-Fi movie
third_most_popular_sci_fi = sorted_sci_fi_movies.iloc[2]

# Print the title of the third most popular Sci-Fi movie
print("The third most popular Sci-Fi movie based on number of user ratings is:", third_most_popular_sci_fi['title'])
# Out:
# The third most popular Sci-Fi movie based on number of user ratings is: Jurassic Park (1993)

# %%
links.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
links[links['imdbId']==8391976]
# Out:
#       movieId   imdbId    tmdbId
# 9740   193587  8391976  483455.0

# %%
import requests
import numpy as np
from bs4 import BeautifulSoup

def scrapper(imdbId):
    id = str(int(imdbId))
    n_zeroes = 7 - len(id)
    new_id = "0" * n_zeroes + id
    URL = f"https://www.imdb.com/title/tt{new_id}/"
    request_header = {
        'Content-Type': 'text/html; charset=UTF-8',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/119.0',
        'Accept-Encoding': 'gzip, deflate, br'
    }
    response = requests.get(URL, headers=request_header)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        imdb_rating_tag = soup.find('span', itemprop='ratingValue')
        return imdb_rating_tag.text.strip() if imdb_rating_tag else np.nan
    else:
        print(f"Failed to fetch IMDb rating for {URL}")
        return np.nan

# %%
m1
# Out:
#         userId  movieId  rating   timestamp                           title  \
# 0            1        1     4.0   964982703                Toy Story (1995)
# 1            1        3     4.0   964981247         Grumpier Old Men (1995)
# 2            1        6     4.0   964982224                     Heat (1995)
# 3            1       47     5.0   964983815     Seven (a.k.a. Se7en) (1995)
# 4            1       50     5.0   964982931      Usual Suspects, The (1995)
# ...        ...      ...     ...         ...                             ...
# 100831     610   166534     4.0  1493848402                    Split (2017)
# 100832     610   168248     5.0  1493850091   John Wick: Chapter Two (2017)
# 100833     610   168250     5.0  1494273047                  Get Out (2017)
# 100834     610   168252     5.0  1493846352                    Logan (2017)
# 100835     610   170875     3.0  1493846415  The Fate of the Furious (2017)
#
# ...

# %%
import pandas as pd

# Sample data for demonstration (replace with your actual data)
links_data = {
    'movieId': [1, 2, 3],
    'imdbId': ['0114709', '0113497', '0113228']
}

links_df = pd.DataFrame(links_data)

# Provided code
import requests
import numpy as np
from bs4 import BeautifulSoup

def scrapper(imdbId):
    id = str(int(imdbId))
    n_zeroes = 7 - len(id)
    new_id = "0" * n_zeroes + id
    URL = f"https://www.imdb.com/title/tt{new_id}/"
    request_header = {
        'Content-Type': 'text/html; charset=UTF-8',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/119.0',
        'Accept-Encoding': 'gzip, deflate, br'
    }
    response = requests.get(URL, headers=request_header)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        imdb_rating_tag = soup.find('span', itemprop='ratingValue')
        return imdb_rating_tag.text.strip() if imdb_rating_tag else np.nan
    else:
        print(f"Failed to fetch IMDb rating for {URL}")
        return np.nan

# Find movieId of the Sci-Fi movie with the highest IMDb rating
sci_fi_movies = []

for index, row in links_df.iterrows():
    movieId = row['movieId']
    genres_response = requests.get(f"https://www.imdb.com/title/tt{row['imdbId']}/genres/")

    if genres_response.status_code == 200:
        genres_soup = BeautifulSoup(genres_response.text, 'html.parser')
        genres = genres_soup.find('div', class_='see-more inline canwrap').text.strip()

        if 'Sci-Fi' in genres:
            imdb_rating = scrapper(row['imdbId'])

            if not pd.isna(imdb_rating):
                sci_fi_movies.append({'movieId': movieId, 'imdbRating': float(imdb_rating)})

if sci_fi_movies:
    highest_rated_sci_fi_movie = max(sci_fi_movies, key=lambda x: x['imdbRating'])
    print(f"The Sci-Fi movie with the highest IMDb rating is MovieID: {highest_rated_sci_fi_movie['movieId']} with rating: {highest_rated_sci_fi_movie['imdbRating']}")
else:
    print("No valid IMDb ratings found for Sci-Fi movies.")
# Out:
# No valid IMDb ratings found for Sci-Fi movies.

# %%
# m1[m1['genres']=='Sci-Fi']
sci =m1[m1['genres'] == 'Sci-Fi']
sci.max()
# Out:
# userId                  610
# movieId              176371
# rating                  5.0
# timestamp        1537158234
# title        Zone 39 (1997)
# genres               Sci-Fi
# imdbId              2724064
# tmdbId             335984.0
# tag                     NaN
# dtype: object

# %%
m1[(m1['genres'] == 'Sci-Fi') & (m1['imdbId'] == 2724064 )]
# Out:
#         userId  movieId  rating   timestamp             title  genres  \
# 61693      408   103596     3.0  1468361712  Sharknado (2013)  Sci-Fi
# 70152      448   103596     1.5  1376739104  Sharknado (2013)  Sci-Fi
# 88009      567   103596     0.5  1525289777  Sharknado (2013)  Sci-Fi
# 100636     610   103596     2.5  1493848505  Sharknado (2013)  Sci-Fi
#
#          imdbId    tmdbId  tag
# 61693   2724064  205321.0  NaN
# 70152   2724064  205321.0  NaN
# 88009   2724064  205321.0  NaN
# 100636  2724064  205321.0  NaN
